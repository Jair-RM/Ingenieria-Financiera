# %% [markdown]
# <a href="https://colab.research.google.com/github/Jair-RM/Ingenieria-Financiera/blob/main/01_get_current_weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def get_current_weather(city_name: str, api_key: str) -> dict:
    base_url = "https://api.openweathermap.org/data/2.5/weather"
    params = {
        "q": city_name,
        "appid": api_key,
        "units": "metric"  # Use "imperial" for Fahrenheit
    }

    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()  # Raise HTTPError for bad responses

        data = response.json()

        # Parse desired fields
        weather_info = {
            "city": data.get("name"),
            "temperature_celsius": data["main"]["temp"],
            "weather_description": data["weather"][0]["description"],
            "humidity_percent": data["main"]["humidity"],
            "wind_speed_m_s": data["wind"]["speed"]
        }

        return weather_info

    except requests.RequestException as e:
        return {"error": str(e)}
    except KeyError as e:
        return {"error": f"Missing field in response: {e}"}

# %%
response = get_current_weather("Mexico city", "7983935f6fda377ebebd6a3a7a67ce86")

# %%
response
# Out:
# {'city': 'Mexico City',
#  'temperature_celsius': 21.64,
#  'weather_description': 'clear sky',
#  'humidity_percent': 4,
#  'wind_speed_m_s': 7.72}

# %%
requests.get("https://www.eluniversal.com.mx/tag/finanzas/").text
# Out:
# '<!DOCTYPE html><html lang="es"><head><link rel="preload" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" as="script"/><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><title>finanzas | El Universal</title><link rel="shortcut icon" href="/pf/resources/website/eluniversal/favicon.ico?d=1286" type="image/vnd.microsoft.icon"/><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="lang" content="es"/><meta name="abstract" content="El Universal"/><meta name="robots" content="follow, index, max-image-preview:large, max-snippet:-1"/><meta http-equiv="x-dns-prefetch-contro" content="on"/><meta name="description" content="Noticias de finanzas"/><meta name="keywords" content="finanzas, videos finanzas, fotos finanzas"/><meta property="fb:app_id" content="163316950407128"/><meta property="fb:pages"/><meta property="og:type" content="website"/><me
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(requests.get("https://www.eluniversal.com.mx/tag/finanzas/").text)

# %%
for a in soup.find_all("a", attrs={"class": "eventListCards"}):
  print(a.text)
# Out:
# Estados, lejos de alcanzar una total fortaleza fiscal; sólo 4 entidades tienen buen manejo de sus finanzas: consultora
#
# Lo que se ve venir: el nacionalismo económico
#
# Finanzas solidarias: el papel clave de las cooperativas en el desarrollo económico de México
#
# Supuestos heroicos
#
# Se incrementa hasta 100% cuentas mulas en Latinoamérica; menores de 21 años, los más involucrados en lavado de dinero
#
# Exceso de confianza de usuarios, entrada para estafas financieras; falta de precaución, otra de las causas, alerta HSBC
#
# Mejora Yucatán su calificación financiera; se ubica entre las entidades con alta confianza en inversiones
#
# El futuro de las finanzas no espera: modernizarse o quedar atrás
#
# Fintech en México: cada vez más fuertes
#
# Markets Media Group entrega sus Premios Mujeres en Finanzas América Latina; Magdalena Carral recibe galardón Lifetime Achievement
